# %% [markdown]
# #

# %%
import pandas
import spacy
from ast import literal_eval
import re 
from collections import Counter
import checklist
from checklist.editor import Editor
from checklist.perturb import Perturb
import numpy as np
import openpyxl

nlp = spacy.load('en_core_web_sm')

# %%
def read_csv_subject(subject):
    """
    Quick function to retrieve the subject data from csvs. Data will contain both dutch and english. 
    Note that this will always only return the training set
    """
    return pandas.read_csv(f'E:/ArriaThesis/MscThesis/Data/Cleaned_Continuous/{subject}/Train.csv')


def write_to_csv(data, iteration):
    """
    Data = dataset
    Iteration = iteration to determine the dataset split
    data_type = is the dataset RDF or text
    """
    labels = ['Train', 'Dev', 'Test']

    if isinstance(data, pandas.DataFrame):
        print(f'data is a dataframe')

    try:
        print("Entered try check")
        if (os.path.exists(f'E:/ArriaThesis/MscThesis/Data/Augmented_data/{labels[iteration]}') == False) :
            save_path = 'E:/ArriaThesis/MscThesis/Data/Augmented_data/' 
            name_of_file = f'{labels[iteration]}'
            output_file = os.path.join(save_path,f'{name_of_file}.csv')
            data.to_csv(output_file, index=False, encoding = 'utf-8')
    except:
        print(f'file for {labels[iteration]} already exists')


def filter_on_attribute_in_input(data, AttributeName):
    """
    Filters a dataframe based on a chosen attribute
    Input: Dataframe, chosen attribute name
    Returns filtered dataframe
    """
    return data[data['input'].str.contains(f"{AttributeName}")]


def prepare_attribute_values(data_list):
    """
    Gets the valeus that correspond with the chosen attribute. This list is used when changing out the data
    Input: Dataframe input containing string of rdf values
    Returns a dataframe of inputs
    """
    
    RDF = []
    for rdf_iteration, rdf in enumerate(data_list):
        RDF.append(literal_eval(rdf))

    return RDF


def get_attribute_values(data, chosen_attribute):
    data = prepare_attribute_values(data)

    stored_values = []

    for element in data:
        for attribute in element:
            if chosen_attribute in attribute:
                split_attributes = attribute.split(' | ')
                value = split_attributes[1]
                if "'" not in value:
                    stored_values.append(value)

    return set(stored_values)


def prepare_data_for_checklist(data):
    """
    Function that transforms the data so that checklist methods can be used.
    Input: Dataframe with columns input and output
    Returns: An input and an output dataframe
    """
    data_input = list(nlp.pipe(data['input']))
    data_output = list(nlp.pipe(data['output']))
    return data_input, data_output

def calculate_difference(highest_value, current_value):
    """
    Function that calculates how much more data is needed to be augmented to reach the cap of augmentation    
    """
    if isinstance(highest_value, int) and isinstance(current_value, int):
        return highest_value - current_value
    else:
        return ValueError 


def retrieve_and_change_values(data_input, data_texts, attribute_values, desired_additional_data_amount, chosen_attribute_count):
    potential_values = attribute_values

    amount_to_be_created = calculate_difference(desired_additional_data_amount, chosen_attribute_count)

    clean_df = pandas.DataFrame({'input' : [], 'output': []})


    while (len(clean_df['input']) < amount_to_be_created):
        for text_id, text in enumerate(data_texts):
            for attributes in potential_values:
                if '(' in attributes:
                    attributes = attributes.replace('(', '')
                if ')' in attributes:
                    attributes = attributes.replace(')', '')
                if '_' in attributes:
                    attributes = attributes.replace('_', ' ')
                   
                try: 
                    if re.search(r'\b%s\b' % attributes, text.text):
                        
                        for swapping_value in potential_values:
                            # if the value is not found in the text, create a new text with the different value
                            if swapping_value != attributes:
                                # this REGEX reads as find the exact attribute in the input text that corresponds with the looked at text and replace it with the chosen swapping value
                                new_input = re.sub(r'\b%s\b' % attributes, swapping_value, data_input[text_id].text)
                                
                                text_appropriate_value = swapping_value.replace('_', ' ')
                                # this REGEX reads as find the exact attribute in the text.text and replace it with text_appropriate_value
                                new_text = re.sub(r'\b%s\b' % attributes, text_appropriate_value, text.text)
                                
                                full_new_input = [new_input, new_text]

                                # make sure we do not create too much data
                                if len(clean_df['input']) < amount_to_be_created:
                                    clean_df.loc[len(clean_df)] = full_new_input
                                else:
                                    break
                except:
                    print(f'text.text   {text.text}')
                    print(f'attributes   {attributes}')

    return clean_df
 

def get_attribute_count_from_dataframe(dataframe):
    prep_list = []
    total_attributes = []

    for element_id, element in enumerate(dataframe.loc[:, 'input']):
        prep_list.append(literal_eval(element))

    dataframe['check'] = prep_list

    for inputs in dataframe['check']:
        for attributes in inputs:
            split_attributes = attributes.split(' | ')
            total_attributes.append(split_attributes[0])
   

    return Counter(total_attributes)
    
def subject_data_addition(attribute_lists, subject, expected_data_amount):
    subject_df = read_csv_subject(subject)

    subject_df_expanded = subject_df.copy(deep=True)
    # input contains several attributes, so starting with lowest occuring attribute will lower the chance of a data blow-upp
    
    for language_split_list in attribute_lists:

        language_split_list.reverse()

        for attribute in language_split_list:
            subject_df_filtered = subject_df[subject_df["input"].str.contains(f'{attribute}')==True]

            current_total_attribute_count = get_attribute_count_from_dataframe(subject_df_filtered)
            current_attribute_count = current_total_attribute_count[attribute]

            values = get_attribute_values(subject_df_filtered['input'], f"{attribute}")

            Prepped_data_input, Prepped_data_output = prepare_data_for_checklist(subject_df_filtered)

            additional_data = retrieve_and_change_values(Prepped_data_input, Prepped_data_output, values, expected_data_amount, current_attribute_count)
            
            subject_df_expanded = subject_df_expanded.append(additional_data, ignore_index=True)
    return subject_df_expanded

# %% [markdown]
# ## Data Augmentation Training Set
# Below are the records identified occurring less than 250 times, thus needing for augmentation

# %%
Sport_attributes_NL = ['assistName', 'chanceForType', 'coachName','teamStandings',
'assistType','playerName', 'stadiumPlayed','numberOfPoints','homeAway','matchStreakNumber','hasTiedTeam','matchStreakType','playerNationality','numberOfSeasonGoals',
'numberOfMatchesPlayed','numberOfMatchGoals','tackleRecipientName','tackleGiverName','substituteName','chanceForNumber','twiceYellowName','nextMatchTeam','redCardName','refereeName',
'injuredName','playerAge','disallowedGoalType','injuryType','halfTimeScore','disallowedGoalName','nextMatchHomeAway','suspendedName', 'nextMatchDate','chanceForNationality','formationTeam']

Sport_attributes_Eng = ['RBI', 'hasWonTeam', 'finalScore', 'outNumber', 'hasLostTeam', 'homeRunNumber', 'baseNumber',
 'strikeOutNumber', 'startsNumber', 'pitchResultNumber', 'competitionName', 'walkNumber', 'locationPlayed', 'managerName', 'scoreNumber', 'onBaseNumber', 'pitchType', 'batterHitsTries', 'pitcherSaveRecord', 'ERA', 'teamStandings',
 'injuryType', 'homeAway', 'pitchNumber', 'standingsGames', 'hasScored', 'battingAverage', 'teamRecord', 'earnedRunsNumber', 'throwDirection', 'pitchCount', 'battersFacedNumber', 'pitchesTotalThrown', 'atBatNumber', 'gameTally', 'matchStreakNumber', 
 'battingLineupNumber', 'umpireName', 'catchType', 'winningPercentage', 'matchStreakType', 'umpireType', 'unearnedRunsNumber', 'baseStolen', 'strikeNumber',
 'retireNumber', 'stealNumber', 'baseReachedNumber', 'leftOnBase', 'basesRan', 'catcherName', 'isOut', 'errorNumber', 'numberOfStarts']

Stock_NL = ['stockChangePercentage', 'timePoint', 'exchangeName', 'moneyAmount', 'stockPoints']

Stock_Eng = ['PERCENT', 'exchangeName', 'LOC', 'stockPoints', 'MONEY', 'TICKER', 'ORDINAL']

Incident_NL = ['victimStatus', 'victimGender', 'victimVehicle', 'incidentType', 'location', 'datetime', 'suspectVehicle', 'victimAge', 'victimAddress', 'cause', 'victimDescription',
                'victimAmount', 'suspectGender', 'suspectStatus', 'suspectAge', 'suspectAddress', 'suspectDescription', 'suspectAmount', 'victimName']

Incident_Eng = ['victimNumber', 'victimStatus', 'accidentAddress', 'shootingType', 'accidentDate', 'victimGender', 'victimAge', 'victimName', 'suspectName', 'hospitalName', 'suspectStatus', 'suspectGender', 'suspectAge', 
                'suspectNumber', 'victimBased', 'victimAge_Group', 'victimOccupation', 'numberOfRoundsFired', 'suspectWeapon', 'suspectVehicle', 'suspectBased', 'personnelArrivedTime', 'shootingNumber', 'prisonName',
                 'suspectAge_Group', 'victimRace', 'suspectRace', 'suspectDescription', 'suspectHeight', 'suspectOccupation', 'victimVehicle', 'suspectWeight']

Weather_NL = ['windDirection', 'cloudAmount', 'weatherIntensity', 'weatherFrequency', 'weatherArea', 'minimumTemperature', 'temperatureCelsius', 'maximumTemperature', 'weatherOccurringChance', 'compassDirection', 'windChange', 
                'cloudType', 'cloudChange', 'weatherChange', 'windSpeedBft', 'gustAmount', 'gustVelocity', 'temperatureChange', 'temperatureHotCold', 'precipitationAmount', 'gustChange', 'windType', 'windTurning', 'snowAmount']

Weather_Eng = ['weatherIntensity', 'temperatureCelsius', 'temperatureHotCold', 'windAmount', 'weatherOccurringChance', 'maximumTemperature', 'cloudAmount', 'weatherFrequency', 'temperatureChange', 'minimumTemperature', 'windDirection', 
                'weatherChange', 'windSpeedBft', 'compassDirection', 'snowAmount', 'windChange', 'gustAmount', 'precipitationAmount', 'cloudChange', 'weatherArea', 'gustVelocity', 'gustChange', 'cloudType', 'sunSetTime', 'sunRiseTime']

# %%
Weather_added = subject_data_addition([Weather_NL, Weather_Eng], 'Weather', 250) 
Stock_added = subject_data_addition([Stock_NL, Stock_Eng], 'Stocks', 250)
Sport_added = subject_data_addition([Sport_attributes_NL, Sport_attributes_Eng], 'Sports', 250)
Incident_added = subject_data_addition([Incident_NL, Incident_Eng], 'Incidents', 250)
# Out:
# e:\Anaconda\envs\CudaSupEnv\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
full_added_data = Sport_added.append(Weather_added, ignore_index=True)
full_added_data = full_added_data.append(Incident_added, ignore_index=True)
full_added_data_train = full_added_data.append(Stock_added, ignore_index=True)

# %%
full_added_data_train = full_added_data_train.drop(columns=['check'])
# Out:
# data is a dataframe
# Entered try check

# %% [markdown]
# ### Augmentation Check and Removal of poor additions

# %%
full_count = get_attribute_count_from_dataframe(full_added_data_train)
full_count
# Out:
# Counter({'batterName': 7974,
#          'finalScore': 1234,
#          'gameTally': 329,
#          'hasLostTeam': 820,
#          'hasWonTeam': 992,
#          'hitNumber': 1421,
#          'homeRunNumber': 616,
#          'matchDate': 1816,
#          'pitchResult': 4953,
#          'runNumber': 1429,
#          'competitionName': 695,
#          'baseReachedNumber': 353,
#          'pitchResultNumber': 789,
#          'batterHitsTries': 401,
#          'strikingType': 1514,
#          'teamName': 10671,
#          'winLossType': 1689,
#          'umpireName': 565,
#          'umpireType': 464,
#          'locationPlayed': 616,
#          'inningNumber': 3282,
#          'pitcherName': 5923,
#          'scoreNumber': 759,
#          'scoreTally': 829,
#          'strikeTrajectory': 1073,
#          'gameNumber': 1605,
#          'RBI': 467,
#          'outNumber': 1191,
#          'presidentName': 1,
#          'fielderName': 1010,
#          'fielderPosition': 1371,
#          'baseNumber': 861,
#          'throwDirection': 360,
#          'inningsPitched': 1111,
#          'pitcherRecord': 1340,
#          'pitchType': 355,
#          'strikeOutNumber': 953,
#          'battersFacedNumber': 394,
#          'pitchNumber': 454,
#          'pitchesTotalThrown': 374,
#          'walkNumber': 280,
#          'startsNumber': 739,
#          'injuryType': 841,
#          'atBatNumber': 442,
#          'pitchCount': 405,
#          'battingAverage': 390,
#          'managerName': 624,
#          'pitcherSaveRecord': 423,
#          'winLossRecord': 1023,
#          'homeAway': 503,
#          'standingsGames': 250,
#          'ERA': 324,
#          'unearnedRunsNumber': 284,
#          'battingLineupNumber': 371,
#          'onBaseNumber': 360,
#          'matchStreakNumber': 460,
#          'baseStolen': 312,
#          'hasScored': 436,
#          'matchStreakType': 547,
#          'teamStandings': 834,
#          'leftOnBase': 250,
#          'earnedRunsNumber': 216,
#          'runAverage': 1,
#          'stealNumber': 443,
#          'teamRecord': 250,
#          'catchType': 250,
#          'winningPercentage': 564,
#          'strikeNumber': 278,
#          'basesRan': 274,
#          'retireNumber': 250,
#          'catcherName': 372,
#          'isOut': 250,
#          'errorNumber': 250,
#          'numberOfStarts': 250,
#          'inningScore': 1,
#          'goalName': 1394,
#          'matchTime': 2477,
#          'positionOfPlayer': 946,
#          'stadiumPlayed': 464,
#          'chanceForName': 764,
#          'goalkeeperName': 605,
#          'assistName': 471,
#          'assistType': 500,
#          'goalScore': 947,
#          'goalType': 1058,
#          'chanceForType': 571,
#          'playerAge': 250,
#          'numberOfPoints': 517,
#          'refereeName': 307,
#          'tackleGiverName': 609,
#          'injuredName': 294,
#          'suspendedName': 290,
#          'hasTiedTeam': 292,
#          'numberOfMatchesPlayed': 386,
#          'coachName': 685,
#          'chanceForNumber': 553,
#          'playerName': 554,
#          'numberOfMatchGoals': 283,
#          'numberOfSeasonGoals': 303,
#          'disallowedGoalName': 429,
#          'disallowedGoalType': 539,
#          'tackleRecipientName': 625,
#          'playerNationality': 318,
#          'twiceYellowName': 316,
#          'redCardName': 305,
#          'substituteName': 335,
#          'nextMatchHomeAway': 507,
#          'nextMatchTeam': 819,
#          'halfTimeScore': 258,
#          'nextMatchDate': 572,
#          'chanceForNationality': 277,
#          'formationTeam': 250,
#          'maximumTemperature': 663,
#          'locationArea': 4794,
#          'timePoint': 5747,
#          'weatherIntensity': 1094,
#          'weatherType': 5020,
#          'minimumTemperature': 306,
#          'temperatureCelsius': 977,
#          'cloudChange': 426,
#          'cloudAmount': 790,
#          'snowAmount': 458,
#          'windAmount': 2101,
#          'weatherFrequency': 774,
#          'weatherArea': 475,
#          'temperatureChange': 370,
#          'weatherOccurringChance': 826,
#          'gustAmount': 1037,
#          'gustVelocity': 683,
#          'compassDirection': 352,
#          'temperatureHotCold': 447,
#          'windDirection': 1228,
#          'weatherChange': 411,
#          'windChange': 365,
#          'windSpeedBft': 1128,
#          'precipitationAmount': 582,
#          'gustChange': 492,
#          'cloudType': 404,
#          'sunSetTime': 374,
#          'sunRiseTime': 330,
#          'windType': 250,
#          'windTurning': 250,
#          'shootingType': 1421,
#          'suspectGender': 1303,
#          'suspectNumber': 598,
#          'suspectStatus': 1334,
#          'accidentAddress': 1355,
#          'accidentDate': 854,
#          'victimNumber': 1275,
#          'victimStatus': 2602,
#          'suspectAge': 1459,
#          'suspectName': 1972,
#          'suspectDescription': 740,
#          'suspectHeight': 636,
#          'suspectWeight': 511,
#          'takenToHospital': 649,
#          'victimGender': 1805,
#          'victimAge': 1324,
#          'victimBased': 266,
#          'hospitalName': 263,
#          'victimName': 835,
#          'numberOfRoundsFired': 370,
#          'suspectWeapon': 496,
#          'victimAge_Group': 307,
#          'victimRace': 250,
#          'suspectVehicle': 741,
#          'shootingNumber': 250,
#          'personnelArrivedTime': 250,
#          'suspectOccupation': 264,
#          'suspectBased': 281,
#          'victimOccupation': 282,
#          'prisonName': 284,
#          'suspectAge_Group': 364,
#          'victimVehicle': 718,
#          'suspectRace': 555,
#          'datetime': 569,
#          'incidentType': 697,
#          'victimAddress': 392,
#          'location': 712,
#          'suspectAddress': 250,
#          'victimDescription': 286,
#          'victimAmount': 266,
#          'cause': 250,
#          'suspectAmount': 314,
#          'DATE': 1441,
#          'LOC': 832,
#          'ORDINAL': 250,
#          'ORG': 1355,
#          'stockChange': 2531,
#          'MONEY': 431,
#          'PERCENT': 952,
#          'exchangeName': 1277,
#          'stockPoints': 712,
#          'TICKER': 257,
#          'stockChangePercentage': 1252,
#          'companyName': 1675,
#          'moneyAmount': 498,
#          'locationName': 1287})

# %%
poor_additions = [ 'single','127th','three','87th','eight','nine-RBI','25','doubles','12','299','RBI_singles','83','four','102nd','triple','seven','90','10','109th','groundout','11','one','25th','six',
'singles','100','first','RBI-single','94','102','an','second','15','19','triples','double','13','Seven','31','48','39','two','RBIs','nine','four-RBI','no','five','68']

# %%
for element_id, element in enumerate(full_added_data_train['check']):
    for l in element:
        split_attributes = l.split(' | ')
        attribute = split_attributes[0]
        if attribute in poor_additions: 
            full_added_data_train = full_added_data_train.drop(element_id)

# %%
write_to_csv(full_added_data_train, 0)

# %%
test = pandas.read_csv("E:/ArriaThesis/MscThesis/Data/Augmented_data/Test.csv")

# %%
full_count_test = get_attribute_count_from_dataframe(test)
# Out:
# ['victimGender | men', 'victimNumber | three', 'victimNumber | two', 'victimStatus | critical_injuries', 'shootingType | shot']
# ['victimGender | men', 'victimNumber | three', 'victimNumber | two', 'victimStatus | critical_injuries', 'shootingType | shot']
# ['victimGender | men', 'victimNumber | three', 'victimNumber | two', 'victimStatus | critical_injuries', 'shootingType | shot']
# ['victimGender | men', 'victimNumber | three', 'victimNumber | two', 'victimStatus | critical_injuries', 'shootingType | shot']
# ['victimGender | men', 'victimNumber | three', 'victimNumber | two', 'victimStatus | critical_injuries', 'shootingType | shot']
# ['victimAge_Group | 19_to_21', 'victimGender | men', 'victimStatus | wonded']
# ['victimAge_Group | 19_to_21', 'victimGender | men', 'victimStatus | wonded']
# ['victimAge_Group | 19_to_21', 'victimGender | men', 'victimStatus | wonded']
# ['accidentAddress | Greyhound_bus', 'accidentDate | around_1:30_a.m.', 'shootingType | shooting', 'location | Lebec', 'datetime | Monday_morning']
# ['accidentAddress | Greyhound_bus', 'accidentDate | around_1:30_a.m.', 'shootingType | shooting', 'location | Lebec', 'datetime | Monday_morning']
# ['accidentAddress | Greyhound_bus', 'accidentDate | around_1:30_a.m.', 'shootingType | shooting', 'location | Lebec', 'datetime | Monday_morning']
# ['accidentAddress | Greyhound_bus', 'accidentDate | around_1:30_a.m.', 'shootingType | shooting', 'location | Lebec', 'datetime | Monday_morning']
# ['accidentAddress | Greyhound_bus', 'accidentDate | around_1:30_a.m.', 'shootingType | shooting', 'location | Lebec', 'datetime | Monday_morning']
# ['suspectStatus | arrested', 'suspectWeapon | gun', 'suspectStatus | left_the_bus_and_gun_voluntarily', 'victimStatus | disarmed_the_suspect', 'datetime | after_the_shooting']
# ['suspectStatus | arrested', 'suspectWeapon | gun', 'suspectStatus | left_the_bus_and_gun_voluntarily', 'victimStatus | disarmed_the_suspect', 'datetime | after_the_shooting']
# ['suspectStatus | arrested', 'suspectWeapon | gun', 'suspectStatus | left_the_bus_and_gun_voluntarily', 'victimStatus | disarmed_the_suspect', 'datetime | after_the_shooting']
# ['suspectStatus | arrested', 'suspectWeapon | gun', 'suspectStatus | left_the_bus_and_gun_voluntarily', 'victimStatus | disarmed_the_suspect', 'datetime | after_the_shooting']
# ['suspectStatus | arrested', 'suspectWeapon | gun', 'suspectStatus | left_the_bus_and_gun_voluntarily', 'victimStatus | disarmed_the_suspect', 'datetime | after_the_shooting']
# ['victimStatus | pronounced_dead', 'ORG | Medic']
# ['victimStatus | pronounced_dead', 'ORG | Medic']
# ['victimName | Adrian_Potts', 'ORG | Police', 'datetime | Saturday_night']
# ['victimName | Adrian_Potts', 'ORG | Police', 'datetime | Saturday_night']
# ['victimName | Adrian_Potts', 'ORG | Police', 'datetime | Saturday_night']
# ['suspectStatus | going_west', 'suspectVehicle | gray_Nissan_Altima', 'shootingType | fired']
# ['suspectStatus | going_west', 'suspectVehicle | gray_Nissan_Altima', 'shootingType | fired']
# ['suspectStatus | going_west', 'suspectVehicle | gray_Nissan_Altima', 'shootingType | fired']
# ['victimAge_Group | child', 'victimNumber | One', 'victimNumber | other', 'victimStatus | shot_in_the_leg', 'victimStatus | shot_in_the_arm']
# ['victimAge_Group | child', 'victimNumber | One', 'victimNumber | other', 'victimStatus | shot_in_the_leg', 'victimStatus | shot_in_the_arm']
# ['victimAge_Group | child', 'victimNumber | One', 'victimNumber | other', 'victimStatus | shot_in_the_leg', 'victimStatus | shot_in_the_arm']
# ['victimAge_Group | child', 'victimNumber | One', 'victimNumber | other', 'victimStatus | shot_in_the_leg', 'victimStatus | shot_in_the_arm']
# ['victimAge_Group | child', 'victimNumber | One', 'victimNumber | other', 'victimStatus | shot_in_the_leg', 'victimStatus | shot_in_the_arm']
# ['victimAge | 19-year-old', 'victimAge | 20-year-old', 'victimGender | men', 'victimNumber | two', 'victimStatus | shot_in_the_leg']
# ['victimAge | 19-year-old', 'victimAge | 20-year-old', 'victimGender | men', 'victimNumber | two', 'victimStatus | shot_in_the_leg']
# ['victimAge | 19-year-old', 'victimAge | 20-year-old', 'victimGender | men', 'victimNumber | two', 'victimStatus | shot_in_the_leg']
# ['victimAge | 19-year-old', 'victimAge | 20-year-old', 'victimGender | men', 'victimNumber | two', 'victimStatus | shot_in_the_leg']
# ['victimAge | 19-year-old', 'victimAge | 20-year-old', 'victimGender | men', 'victimNumber | two', 'victimStatus | shot_in_the_leg']
# ['victimNumber | One', 'victimStatus | serious_condition', 'victimNumber | other', 'victimStatus | minor_injuries']
# ['victimNumber | One', 'victimStatus | serious_condition', 'victimNumber | other', 'victimStatus | minor_injuries']
# ['victimNumber | One', 'victimStatus | serious_condition', 'victimNumber | other', 'victimStatus | minor_injuries']
# ['victimNumber | One', 'victimStatus | serious_condition', 'victimNumber | other', 'victimStatus | minor_injuries']
# ['takenToHospital | True', 'victimNumber | four', 'hospitalName | Rochester_General_Hospital', 'victimStatus | gunshot_victims']
# ['takenToHospital | True', 'victimNumber | four', 'hospitalName | Rochester_General_Hospital', 'victimStatus | gunshot_victims']
# ['takenToHospital | True', 'victimNumber | four', 'hospitalName | Rochester_General_Hospital', 'victimStatus | gunshot_victims']
# ['takenToHospital | True', 'victimNumber | four', 'hospitalName | Rochester_General_Hospital', 'victimStatus | gunshot_victims']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['victimName | Patrick_Carter', 'victimName | Rickey_Harvey', 'victimName | Joel_Allen', 'victimName | Darelle_Scott', 'victimAge | 29', 'victimAge | 34', 'victimAge | 26', 'victimAge | 26', 'victimStatus | shot_at_least_once_in_the_upper_body']
# ['incidentType | details_unknown']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimNumber | one', 'victimNumber | one', 'victimNumber | three', 'victimGender | men', 'victimGender | boy', 'victimGender | girl', 'victimStatus | hit']
# ['victimStatus | nonlethal_injuries', 'victimNumber | other']
# ['victimStatus | nonlethal_injuries', 'victimNumber | other']
# ['victimAge_Group | children', 'incidentType | not_know', 'ORG | Ramos']
# ['victimAge_Group | children', 'incidentType | not_know', 'ORG | Ramos']
# ['victimAge_Group | children', 'incidentType | not_know', 'ORG | Ramos']
# ['shootingType | shooting', 'cause  | unknown_if_gang-related', 'victimStatus | targeted']
# ['shootingType | shooting', 'cause  | unknown_if_gang-related', 'victimStatus | targeted']
# ['shootingType | shooting', 'cause  | unknown_if_gang-related', 'victimStatus | targeted']
# ['accidentAddress | parking_lot', 'victimNumber | large_group_of_people', 'suspectDescription | gunman', 'shootingType | shooting']
# ['accidentAddress | parking_lot', 'victimNumber | large_group_of_people', 'suspectDescription | gunman', 'shootingType | shooting']
# ['accidentAddress | parking_lot', 'victimNumber | large_group_of_people', 'suspectDescription | gunman', 'shootingType | shooting']
# ['accidentAddress | parking_lot', 'victimNumber | large_group_of_people', 'suspectDescription | gunman', 'shootingType | shooting']
# ['suspectGender | man', 'suspectRace | black', 'suspectVehicle | white_SUV', 'suspectStatus | fled']
# ['suspectGender | man', 'suspectRace | black', 'suspectVehicle | white_SUV', 'suspectStatus | fled']
# ['suspectGender | man', 'suspectRace | black', 'suspectVehicle | white_SUV', 'suspectStatus | fled']
# ['suspectGender | man', 'suspectRace | black', 'suspectVehicle | white_SUV', 'suspectStatus | fled']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['shootingType | shooting', 'incidentType | interrupted_briefly', 'cause | shooting', 'location | Edison_High_School_two_blocks_away', 'competitionName | Division_III_boys_water_polo_semi-final', 'teamName | Edison', 'teamName | Exeter_High']
# ['suspectName | Bishop_Henderson', 'victimGender | man', 'victimStatus | shot_in_the_face', 'suspectStatus | charged_with_assault']
# ['suspectName | Bishop_Henderson', 'victimGender | man', 'victimStatus | shot_in_the_face', 'suspectStatus | charged_with_assault']
# ['suspectName | Bishop_Henderson', 'victimGender | man', 'victimStatus | shot_in_the_face', 'suspectStatus | charged_with_assault']
# ['suspectName | Bishop_Henderson', 'victimGender | man', 'victimStatus | shot_in_the_face', 'suspectStatus | charged_with_assault']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'victimName | Kristal_Avena', 'victimName | Khalil_Carter', 'victimName | Lamar_Lee-Kane', 'victimStatus | deaths', 'supsectStatus | charged_with_three_counts_of_first-degree_murder']
# ['suspectName | Henderson', 'incidentType | do_not_indicate_why_invesigators_believe_Henderson_fired', 'ORG | Court_documents']
# ['suspectName | Henderson', 'incidentType | do_not_indicate_why_invesigators_believe_Henderson_fired', 'ORG | Court_documents']
# ['suspectName | Henderson', 'incidentType | do_not_indicate_why_invesigators_believe_Henderson_fired', 'ORG | Court_documents']
# ['accidentAddress | nightclub', 'accidentDate | around_closing_time', 'shootingType | shootout', 'suspectNumber | groups']
# ['accidentAddress | nightclub', 'accidentDate | around_closing_time', 'shootingType | shootout', 'suspectNumber | groups']
# ['accidentAddress | nightclub', 'accidentDate | around_closing_time', 'shootingType | shootout', 'suspectNumber | groups']
# ['accidentAddress | nightclub', 'accidentDate | around_closing_time', 'shootingType | shootout', 'suspectNumber | groups']
# ['personnelArrivedTime | 1:58_a.m.', 'ORG | Police']
# ['personnelArrivedTime | 1:58_a.m.', 'ORG | Police']
# ['shootingType | gunfire', 'personnelArrivedTime | within_moments', 'location | within_earshot']
# ['shootingType | gunfire', 'personnelArrivedTime | within_moments', 'location | within_earshot']
# ['shootingType | gunfire', 'personnelArrivedTime | within_moments', 'location | within_earshot']
# ['victimNumber | One', 'victimNumber | four', 'takenToHospital | True', 'hospitalName | Mercy_Medical_Center', "hospitalName | Baystate's_trauma_unit"]
# ['victimNumber | One', 'victimNumber | four', 'takenToHospital | True', 'hospitalName | Mercy_Medical_Center', "hospitalName | Baystate's_trauma_unit"]
# ['victimNumber | One', 'victimNumber | four', 'takenToHospital | True', 'hospitalName | Mercy_Medical_Center', "hospitalName | Baystate's_trauma_unit"]
# ['victimNumber | One', 'victimNumber | four', 'takenToHospital | True', 'hospitalName | Mercy_Medical_Center', "hospitalName | Baystate's_trauma_unit"]
# ['victimNumber | One', 'victimNumber | four', 'takenToHospital | True', 'hospitalName | Mercy_Medical_Center', "hospitalName | Baystate's_trauma_unit"]
# ['victimNumber | Some', 'victimStatus | shot_in_the_torso', 'victimNumber | most', 'victimStatus | hit_in_the_arms_or_legs']
# ['victimNumber | Some', 'victimStatus | shot_in_the_torso', 'victimNumber | most', 'victimStatus | hit_in_the_arms_or_legs']
# ['victimNumber | Some', 'victimStatus | shot_in_the_torso', 'victimNumber | most', 'victimStatus | hit_in_the_arms_or_legs']
# ['victimNumber | Some', 'victimStatus | shot_in_the_torso', 'victimNumber | most', 'victimStatus | hit_in_the_arms_or_legs']
# ['accidentAddress | in_the_parking_lot', 'shootingType | gunfire', 'incidentType | despite_police_presence', 'incidentType | police_units_stationed_near_the_emergency_room_entrance_as_a_precaution']
# ['accidentAddress | in_the_parking_lot', 'shootingType | gunfire', 'incidentType | despite_police_presence', 'incidentType | police_units_stationed_near_the_emergency_room_entrance_as_a_precaution']
# ['accidentAddress | in_the_parking_lot', 'shootingType | gunfire', 'incidentType | despite_police_presence', 'incidentType | police_units_stationed_near_the_emergency_room_entrance_as_a_precaution']
# ['accidentAddress | in_the_parking_lot', 'shootingType | gunfire', 'incidentType | despite_police_presence', 'incidentType | police_units_stationed_near_the_emergency_room_entrance_as_a_precaution']
# ['accidentAddress | downtown_outside_Lux', 'shootingType | gunfight', 'suspectNumber | unknown']
# ['accidentAddress | downtown_outside_Lux', 'shootingType | gunfight', 'suspectNumber | unknown']
# ['accidentAddress | downtown_outside_Lux', 'shootingType | gunfight', 'suspectNumber | unknown']
# ['shootingType | incident', 'incidentType | remains_under_investigation']
# ['shootingType | incident', 'incidentType | remains_under_investigation']
# ['accidentDate | approximately_10:29_pm', 'victimStatus | were_walking', 'incidentType | vehicle_passed_by']
# ['accidentDate | approximately_10:29_pm', 'victimStatus | were_walking', 'incidentType | vehicle_passed_by']
# ['accidentDate | approximately_10:29_pm', 'victimStatus | were_walking', 'incidentType | vehicle_passed_by']
# ['victimNumber | four', 'shootingType | shots_fired', 'location | from_the_vehicle']
# ['victimNumber | four', 'shootingType | shots_fired', 'location | from_the_vehicle']
# ['victimNumber | four', 'shootingType | shots_fired', 'location | from_the_vehicle']
# ['takenToHospital | True', 'victimStatus | non-life_threatening_injuries', 'victimNumber | All']
# ['takenToHospital | True', 'victimStatus | non-life_threatening_injuries', 'victimNumber | All']
# ['takenToHospital | True', 'victimStatus | non-life_threatening_injuries', 'victimNumber | All']
# ['accidentAddress | listed_location', 'accidentDate | approximately_11:08_am', 'victimStatus | standing']
# ['accidentAddress | listed_location', 'accidentDate | approximately_11:08_am', 'victimStatus | standing']
# ['accidentAddress | listed_location', 'accidentDate | approximately_11:08_am', 'victimStatus | standing']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['victimAge_Group | adult', 'victimNumber | One', 'victimNumber | three', 'victimStatus | struck_by_the_gunfire', 'victimGender | female', 'victimGender | males']
# ['takenToHospital | True', 'victimNumber | All']
# ['takenToHospital | True', 'victimNumber | All']
# ['victimBased | Southwest,_DC', 'victimAge | 23_year-old', 'victimName | Jasmine_Lashai_Light', 'victimStatus | decedent']
# ['victimBased | Southwest,_DC', 'victimAge | 23_year-old', 'victimName | Jasmine_Lashai_Light', 'victimStatus | decedent']
# ['victimBased | Southwest,_DC', 'victimAge | 23_year-old', 'victimName | Jasmine_Lashai_Light', 'victimStatus | decedent']
# ['victimBased | Southwest,_DC', 'victimAge | 23_year-old', 'victimName | Jasmine_Lashai_Light', 'victimStatus | decedent']
# ['suspectName | Denham', 'suspectStatus | charged_with_animal_abuse,_armed_criminal_action,_tampering_and_second-degree_arson']
# ['suspectName | Denham', 'suspectStatus | charged_with_animal_abuse,_armed_criminal_action,_tampering_and_second-degree_arson']
# ['suspectStatus | taken_into_custody', 'datetime | Feb._21', 'location | northwestern_Arizona']
# ['suspectStatus | taken_into_custody', 'datetime | Feb._21', 'location | northwestern_Arizona']
# ['suspectStatus | taken_into_custody', 'datetime | Feb._21', 'location | northwestern_Arizona']
# ['suspectStatus | arrested', "cause | suspicion_of_stealing_his_grandparents'_car", 'suspectStatus | returned', 'location | Missouri', 'datetime | this_month']
# ['suspectStatus | arrested', "cause | suspicion_of_stealing_his_grandparents'_car", 'suspectStatus | returned', 'location | Missouri', 'datetime | this_month']
# ['suspectStatus | arrested', "cause | suspicion_of_stealing_his_grandparents'_car", 'suspectStatus | returned', 'location | Missouri', 'datetime | this_month']
# ['suspectStatus | arrested', "cause | suspicion_of_stealing_his_grandparents'_car", 'suspectStatus | returned', 'location | Missouri', 'datetime | this_month']
# ['suspectStatus | arrested', "cause | suspicion_of_stealing_his_grandparents'_car", 'suspectStatus | returned', 'location | Missouri', 'datetime | this_month']
# ['accidentAddress | just_down_the_street_from_Castlemont_High_School', 'shootingType | shooting']
# ['accidentAddress | just_down_the_street_from_Castlemont_High_School', 'shootingType | shooting']
# ['victimAge | 18-year-old', 'victimName | withholding_pending_notification_of_next_of_kin']
# ['victimAge | 18-year-old', 'victimName | withholding_pending_notification_of_next_of_kin']
# ['suspectGender | males', 'suspectNumber | 3-4', 'suspectWeapon | handguns', 'victimAge_Group | teens', 'shootingType | firing']
# ['suspectGender | males', 'suspectNumber | 3-4', 'suspectWeapon | handguns', 'victimAge_Group | teens', 'shootingType | firing']
# ['suspectGender | males', 'suspectNumber | 3-4', 'suspectWeapon | handguns', 'victimAge_Group | teens', 'shootingType | firing']
# ['suspectGender | males', 'suspectNumber | 3-4', 'suspectWeapon | handguns', 'victimAge_Group | teens', 'shootingType | firing']
# ['suspectGender | males', 'suspectNumber | 3-4', 'suspectWeapon | handguns', 'victimAge_Group | teens', 'shootingType | firing']
# ['victimAge | 12-year-old', 'victimGender | son', 'incidentType | came_outside_to_investigate', 'cause | shots_got_the_attention']
# ['victimAge | 12-year-old', 'victimGender | son', 'incidentType | came_outside_to_investigate', 'cause | shots_got_the_attention']
# ['victimAge | 12-year-old', 'victimGender | son', 'incidentType | came_outside_to_investigate', 'cause | shots_got_the_attention']
# ['victimAge | 12-year-old', 'victimGender | son', 'incidentType | came_outside_to_investigate', 'cause | shots_got_the_attention']
# ['victimAge | 12-year-old', 'victimStatus | struck_by_a_bullet_in_the_torso', 'incidentType | retreated_back_into_the_store']
# ['victimAge | 12-year-old', 'victimStatus | struck_by_a_bullet_in_the_torso', 'incidentType | retreated_back_into_the_store']
# ['victimAge | 12-year-old', 'victimStatus | struck_by_a_bullet_in_the_torso', 'incidentType | retreated_back_into_the_store']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['hospitalName | University_Hospitals', 'takenToHospital | True', 'victimAge_Group | teens', 'victimNumber | five', 'victimStatus | shot', 'victimNumber | one', 'victimStatus | confined_with_a_gunshot_wound_to_the_head']
# ['suspectDescription | black_or_darkly-colored_hoodies', 'suspectOccupation | juveniles', 'suspectStatus | not_arrested']
# ['suspectDescription | black_or_darkly-colored_hoodies', 'suspectOccupation | juveniles', 'suspectStatus | not_arrested']
# ['suspectDescription | black_or_darkly-colored_hoodies', 'suspectOccupation | juveniles', 'suspectStatus | not_arrested']
# ['victimAge | 27-year-old', 'victimAge | 30-year-old', 'victimStatus | died_of_their_injuries', 'victimName | Devonte_Henneghan', 'victimName | James_Fields_Jr.']
# ['victimAge | 27-year-old', 'victimAge | 30-year-old', 'victimStatus | died_of_their_injuries', 'victimName | Devonte_Henneghan', 'victimName | James_Fields_Jr.']
# ['victimAge | 27-year-old', 'victimAge | 30-year-old', 'victimStatus | died_of_their_injuries', 'victimName | Devonte_Henneghan', 'victimName | James_Fields_Jr.']
# ['victimAge | 27-year-old', 'victimAge | 30-year-old', 'victimStatus | died_of_their_injuries', 'victimName | Devonte_Henneghan', 'victimName | James_Fields_Jr.']
# ['victimAge | 27-year-old', 'victimAge | 30-year-old', 'victimStatus | died_of_their_injuries', 'victimName | Devonte_Henneghan', 'victimName | James_Fields_Jr.']
# ['shootingType | not_a_random_shooting', 'ORG | Detectives', 'incidentType | actively_investigating']
# ['shootingType | not_a_random_shooting', 'ORG | Detectives', 'incidentType | actively_investigating']
# ['shootingType | not_a_random_shooting', 'ORG | Detectives', 'incidentType | actively_investigating']
# ['shootingType | shooting', 'incidentType | asked_to_contact', 'ORG | Violent_Crimes_Tip_Line_at_(912)_525-3124']
# ['shootingType | shooting', 'incidentType | asked_to_contact', 'ORG | Violent_Crimes_Tip_Line_at_(912)_525-3124']
# ['shootingType | shooting', 'incidentType | asked_to_contact', 'ORG | Violent_Crimes_Tip_Line_at_(912)_525-3124']
# ['victimStatus | in_stable_condition', 'victimNumber | All']
# ['victimStatus | in_stable_condition', 'victimNumber | All']
# ['victimNumber | one', 'victimStatus | hit_by_a_bullet', 'incidentType | bullet_richocheted', 'victimNumber | six_others', 'victimStatus | injured']
# ['victimNumber | one', 'victimStatus | hit_by_a_bullet', 'incidentType | bullet_richocheted', 'victimNumber | six_others', 'victimStatus | injured']
# ['victimNumber | one', 'victimStatus | hit_by_a_bullet', 'incidentType | bullet_richocheted', 'victimNumber | six_others', 'victimStatus | injured']
# ['victimNumber | one', 'victimStatus | hit_by_a_bullet', 'incidentType | bullet_richocheted', 'victimNumber | six_others', 'victimStatus | injured']
# ['victimNumber | one', 'victimStatus | hit_by_a_bullet', 'incidentType | bullet_richocheted', 'victimNumber | six_others', 'victimStatus | injured']
# ['suspectGender | man', 'suspectStatus | detained', 'suspectWeapon | gun', 'shootingType | accidentally_went_off']
# ['suspectGender | man', 'suspectStatus | detained', 'suspectWeapon | gun', 'shootingType | accidentally_went_off']
# ['suspectGender | man', 'suspectStatus | detained', 'suspectWeapon | gun', 'shootingType | accidentally_went_off']
# ['suspectGender | man', 'suspectStatus | detained', 'suspectWeapon | gun', 'shootingType | accidentally_went_off']
# ['victimStatus | shot', 'incidentType | did_not_know_the_suspect']
# ['victimStatus | shot', 'incidentType | did_not_know_the_suspect']
# ['victimName | James_McChristian', 'victimBased | same_block_where_he_was_shot', 'victimStatus | pronounced_dead', 'datetime | 2:03_a.m.', 'ORG | Cook_County_Medical_Examiners_Office']
# ['victimName | James_McChristian', 'victimBased | same_block_where_he_was_shot', 'victimStatus | pronounced_dead', 'datetime | 2:03_a.m.', 'ORG | Cook_County_Medical_Examiners_Office']
# ['victimName | James_McChristian', 'victimBased | same_block_where_he_was_shot', 'victimStatus | pronounced_dead', 'datetime | 2:03_a.m.', 'ORG | Cook_County_Medical_Examiners_Office']
# ['victimName | James_McChristian', 'victimBased | same_block_where_he_was_shot', 'victimStatus | pronounced_dead', 'datetime | 2:03_a.m.', 'ORG | Cook_County_Medical_Examiners_Office']
# ['victimName | James_McChristian', 'victimBased | same_block_where_he_was_shot', 'victimStatus | pronounced_dead', 'datetime | 2:03_a.m.', 'ORG | Cook_County_Medical_Examiners_Office']
# ['victimStatus | died_from_a_gunshot_wound_in_his_torso', 'incidentType | autopsy']
# ['victimStatus | died_from_a_gunshot_wound_in_his_torso', 'incidentType | autopsy']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['victimAge | 23-year-old', 'victimAge | 23-year-old', 'victimStatus | hit_in_her_leg_and_was_in_good_condition', 'victimStatus | hit_in_his_shoulder_and_was_in_good_condition', 'victimGender | woman', 'victimGender | male']
# ['suspectName | Kelvin_Clark', 'suspectStatus | bond_set_for_250,000']
# ['suspectName | Kelvin_Clark', 'suspectStatus | bond_set_for_250,000']
# ['shootingType | shooting', 'victimNumber | Six', 'victimNumber | one', 'victimStatus | shot', 'victimStatus | in_critical_condition']
# ['shootingType | shooting', 'victimNumber | Six', 'victimNumber | one', 'victimStatus | shot', 'victimStatus | in_critical_condition']
# ['shootingType | shooting', 'victimNumber | Six', 'victimNumber | one', 'victimStatus | shot', 'victimStatus | in_critical_condition']
# ['shootingType | shooting', 'victimNumber | Six', 'victimNumber | one', 'victimStatus | shot', 'victimStatus | in_critical_condition']
# ['shootingType | shooting', 'victimNumber | Six', 'victimNumber | one', 'victimStatus | shot', 'victimStatus | in_critical_condition']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['accidentAddress | Westport_Art_Fair', 'personnelArrivedTime | around_3:30_a.m.', 'suspectGender | man', 'suspectStatus | get_into_a_car', 'victimNumber | crowd_of_people', 'shootingType | shoot']
# ['victimNumber | One', 'victimNumber | five', 'victimStatus | in_critical_condition', 'victimStatus | non-life_threatening']
# ['victimNumber | One', 'victimNumber | five', 'victimStatus | in_critical_condition', 'victimStatus | non-life_threatening']
# ['victimNumber | One', 'victimNumber | five', 'victimStatus | in_critical_condition', 'victimStatus | non-life_threatening']
# ['victimNumber | One', 'victimNumber | five', 'victimStatus | in_critical_condition', 'victimStatus | non-life_threatening']
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['victimNumber | two', 'victimNumber | two', 'victimGender | men', 'victimGender | women', 'victimStatus | bloodied_bodies', "accidentAddress | large,_blue_two-story_home_in_the_city's_South_Linden_section"]
# ['shootingType | shooting_spree', 'victimGender | her', 'victimStatus | non-life_threatening_injuries', 'incidentType | not_disclosed_if_it_was_related']
# ['shootingType | shooting_spree', 'victimGender | her', 'victimStatus | non-life_threatening_injuries', 'incidentType | not_disclosed_if_it_was_related']
# ['shootingType | shooting_spree', 'victimGender | her', 'victimStatus | non-life_threatening_injuries', 'incidentType | not_disclosed_if_it_was_related']
# ['shootingType | shooting_spree', 'victimGender | her', 'victimStatus | non-life_threatening_injuries', 'incidentType | not_disclosed_if_it_was_related']
# ['victimGender | man', 'victimStatus | died', 'victimName | withheld,_pending_notification_of_next_of_kin']
# ['victimGender | man', 'victimStatus | died', 'victimName | withheld,_pending_notification_of_next_of_kin']
# ['victimGender | man', 'victimStatus | died', 'victimName | withheld,_pending_notification_of_next_of_kin']
# ['shootingType | not_a_mass_shooting', 'suspectDescription | no_suspect_information']
# ['shootingType | not_a_mass_shooting', 'suspectDescription | no_suspect_information']
# ['victimNumber | multiple', 'incidentType | people_screaming', 'incidentType | They_arrived_to_a_chaotic_scene']
# ['victimNumber | multiple', 'incidentType | people_screaming', 'incidentType | They_arrived_to_a_chaotic_scene']
# ['victimNumber | multiple', 'incidentType | people_screaming', 'incidentType | They_arrived_to_a_chaotic_scene']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['hospitalName | Sentara_Norfolk_General_Hospital', 'takenToHospital | True', 'victimNumber | Some', 'victimStatus | treated_by_medics_on_the_scene', 'victimNumber | others', 'victimStatus | taken_by_ambulance', 'location | the_major_trauma_center_in_the_Hampton_Roads_region']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['shootingType | shooting', 'victimGender | male', 'victimNumber | eight', 'victimStatus | died', 'hospitalName | Sentara', 'victimNumber | one', 'datetime | 2:06_a.m.']
# ['takenToHospital | True', 'victimNumber | total_number_of_10', 'incidentType | two_other_hospitals_treating_shooting_victims', 'datetime | as_the_night_went_on']
# ['takenToHospital | True', 'victimNumber | total_number_of_10', 'incidentType | two_other_hospitals_treating_shooting_victims', 'datetime | as_the_night_went_on']
# ['takenToHospital | True', 'victimNumber | total_number_of_10', 'incidentType | two_other_hospitals_treating_shooting_victims', 'datetime | as_the_night_went_on']
# ['takenToHospital | True', 'victimNumber | total_number_of_10', 'incidentType | two_other_hospitals_treating_shooting_victims', 'datetime | as_the_night_went_on']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['victimNumber | Three', 'victimNumber | two', 'victimStatus | nonlife-threatening_gunshot_wounds', 'victimNumber | other', 'victimAge_Group | 21-year-old', 'victimAge | 16-year-old']
# ['accidentAddress | Landview_Drive', 'personnelArrivedTime | 2:26_a.m._Thursday_morning', 'incidentType | shots_fired']
# ['accidentAddress | Landview_Drive', 'personnelArrivedTime | 2:26_a.m._Thursday_morning', 'incidentType | shots_fired']
# ['accidentAddress | Landview_Drive', 'personnelArrivedTime | 2:26_a.m._Thursday_morning', 'incidentType | shots_fired']
# ['takenToHospital | True', 'victimNumber | two', 'victimStatus | shooting_victims']
# ['takenToHospital | True', 'victimNumber | two', 'victimStatus | shooting_victims']
# ['takenToHospital | True', 'victimNumber | two', 'victimStatus | shooting_victims']
# ['victimNumber | One', 'victimStatus | shot_in_the_neck', 'victimStatus | in_critical_condition']
# ['victimNumber | One', 'victimStatus | shot_in_the_neck', 'victimStatus | in_critical_condition']
# ['victimNumber | One', 'victimStatus | shot_in_the_neck', 'victimStatus | in_critical_condition']
# ['victimGender | man', 'victimNumber | One', 'victimStatus | shot_in_the_arm', 'victimStatus | in_stable_condition']
# ['victimGender | man', 'victimNumber | One', 'victimStatus | shot_in_the_arm', 'victimStatus | in_stable_condition']
# ['victimGender | man', 'victimNumber | One', 'victimStatus | shot_in_the_arm', 'victimStatus | in_stable_condition']
# ['victimGender | man', 'victimNumber | One', 'victimStatus | shot_in_the_arm', 'victimStatus | in_stable_condition']
# ['victimGender | men', 'victimNumber | Two', 'victimStatus | serious_but_stable_condition', 'victimStatus | shot_in_the_legs']
# ['victimGender | men', 'victimNumber | Two', 'victimStatus | serious_but_stable_condition', 'victimStatus | shot_in_the_legs']
# ['victimGender | men', 'victimNumber | Two', 'victimStatus | serious_but_stable_condition', 'victimStatus | shot_in_the_legs']
# ['victimGender | men', 'victimNumber | Two', 'victimStatus | serious_but_stable_condition', 'victimStatus | shot_in_the_legs']
# ['suspectGender | man', 'suspectStatus | arrested_without_incident', 'datetime | Wednesday_afternoon', 'ORG | Polcie_Chief_Calvin_Williams_and_Deputy_Chief_Edward_Tomba']
# ['suspectGender | man', 'suspectStatus | arrested_without_incident', 'datetime | Wednesday_afternoon', 'ORG | Polcie_Chief_Calvin_Williams_and_Deputy_Chief_Edward_Tomba']
# ['suspectGender | man', 'suspectStatus | arrested_without_incident', 'datetime | Wednesday_afternoon', 'ORG | Polcie_Chief_Calvin_Williams_and_Deputy_Chief_Edward_Tomba']
# ['suspectGender | man', 'suspectStatus | arrested_without_incident', 'datetime | Wednesday_afternoon', 'ORG | Polcie_Chief_Calvin_Williams_and_Deputy_Chief_Edward_Tomba']
# ['suspectStatus | in_custody', 'suspectStatus | expected_to_be_charged_within_48_hours']
# ['suspectStatus | in_custody', 'suspectStatus | expected_to_be_charged_within_48_hours']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['accidentAddress | East_92nd_Street_home', 'accidentDate | Nov._21', 'suspectDescription | masked', 'victimStatus | killing', 'victimName | Lemon_Bryant', 'victimName | Shaylona_Williams', "victimName | Ja'rio_Taylor", 'victimName | Sherita_Johnson', 'victimAge | 60', 'victimAge | 17', 'victimAge | 18', 'victimAge | 41']
# ['takenToHospital | True', 'victimName | Johnson', 'victimStatus | died_after_delivery', 'victimName | her_child,_Juwan']
# ['takenToHospital | True', 'victimName | Johnson', 'victimStatus | died_after_delivery', 'victimName | her_child,_Juwan']
# ...
# ['goalType | rebound', 'numberOfMatchGoals | beide', 'playerName | Hij', 'cause | stond_op_de_goed_plek', 'matchTime | verdeeld_over_beide_helften']
# ['goalType | rebound', 'numberOfMatchGoals | beide', 'playerName | Hij', 'cause | stond_op_de_goed_plek', 'matchTime | verdeeld_over_beide_helften']
# ['goalType | rebound', 'numberOfMatchGoals | beide', 'playerName | Hij', 'cause | stond_op_de_goed_plek', 'matchTime | verdeeld_over_beide_helften']
# ['goalScore | 1-0', 'teamName | Heerenveen', 'incidentType | reden_tot_klagen', 'cause | geen_strafschop_kreeg', 'hasLostTeam | Herenveen']
# ['goalScore | 1-0', 'teamName | Heerenveen', 'incidentType | reden_tot_klagen', 'cause | geen_strafschop_kreeg', 'hasLostTeam | Herenveen']
# ['goalScore | 1-0', 'teamName | Heerenveen', 'incidentType | reden_tot_klagen', 'cause | geen_strafschop_kreeg', 'hasLostTeam | Herenveen']
# ['goalScore | 1-0', 'teamName | Heerenveen', 'incidentType | reden_tot_klagen', 'cause | geen_strafschop_kreeg', 'hasLostTeam | Herenveen']
# ['goalScore | 1-0', 'teamName | Heerenveen', 'incidentType | reden_tot_klagen', 'cause | geen_strafschop_kreeg', 'hasLostTeam | Herenveen']
# ['playerName | Luciano_Slagveer', 'incidentType | gele_kaart', 'cause | erg_gretig_naar_het_gras', 'incidentType | schwalbe']
# ['playerName | Luciano_Slagveer', 'incidentType | gele_kaart', 'cause | erg_gretig_naar_het_gras', 'incidentType | schwalbe']
# ['playerName | Luciano_Slagveer', 'incidentType | gele_kaart', 'cause | erg_gretig_naar_het_gras', 'incidentType | schwalbe']
# ['playerName | Luciano_Slagveer', 'incidentType | gele_kaart', 'cause | erg_gretig_naar_het_gras', 'incidentType | schwalbe']
# ['teamName | Heerenveen', 'teamName | NEC', 'teamStandings | zevende', 'competitionName | de_competitie', 'teamStandings | 11e']
# ['teamName | Heerenveen', 'teamName | NEC', 'teamStandings | zevende', 'competitionName | de_competitie', 'teamStandings | 11e']
# ['teamName | Heerenveen', 'teamName | NEC', 'teamStandings | zevende', 'competitionName | de_competitie', 'teamStandings | 11e']
# ['teamName | Heerenveen', 'teamName | NEC', 'teamStandings | zevende', 'competitionName | de_competitie', 'teamStandings | 11e']
# ['teamName | Heerenveen', 'teamName | NEC', 'teamStandings | zevende', 'competitionName | de_competitie', 'teamStandings | 11e']
# ['matchTime | drie', 'matchTime | eerste_tien_minuten', 'incidentType | beloofde_weinigs_goeds', 'incidentType | buitengewoonlijk_vermakelijk']
# ['matchTime | drie', 'matchTime | eerste_tien_minuten', 'incidentType | beloofde_weinigs_goeds', 'incidentType | buitengewoonlijk_vermakelijk']
# ['matchTime | drie', 'matchTime | eerste_tien_minuten', 'incidentType | beloofde_weinigs_goeds', 'incidentType | buitengewoonlijk_vermakelijk']
# ['matchTime | drie', 'matchTime | eerste_tien_minuten', 'incidentType | beloofde_weinigs_goeds', 'incidentType | buitengewoonlijk_vermakelijk']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['chanceForName | Danny_Holla', 'chanceForName | Queensy_Menig', 'chanceForType | geblokt_schot', 'chanceForType | volgde_diens_voorbeeld', 'chanceForType | schoot_op_de_paal', 'chanceForName | Mikhail_Rosheuvel']
# ['matchTime | In_de_tweede_helft', 'incidentType | beide_ploegen_vrolijk_verder']
# ['matchTime | In_de_tweede_helft', 'incidentType | beide_ploegen_vrolijk_verder']
# ['teamName | Roda', 'teamRecord | minst_scorende_ploeg', 'competitionName | eredivisie', 'incidentType | geloofde_niet_meer_in_een_treffer', 'incidentType | zette_in_op_een_punt']
# ['teamName | Roda', 'teamRecord | minst_scorende_ploeg', 'competitionName | eredivisie', 'incidentType | geloofde_niet_meer_in_een_treffer', 'incidentType | zette_in_op_een_punt']
# ['teamName | Roda', 'teamRecord | minst_scorende_ploeg', 'competitionName | eredivisie', 'incidentType | geloofde_niet_meer_in_een_treffer', 'incidentType | zette_in_op_een_punt']
# ['teamName | Roda', 'teamRecord | minst_scorende_ploeg', 'competitionName | eredivisie', 'incidentType | geloofde_niet_meer_in_een_treffer', 'incidentType | zette_in_op_een_punt']
# ['teamName | Roda', 'teamRecord | minst_scorende_ploeg', 'competitionName | eredivisie', 'incidentType | geloofde_niet_meer_in_een_treffer', 'incidentType | zette_in_op_een_punt']
# ['teamName | PEC', 'teamName | zwartgele', 'incidentType | probeerde_de_muur_te_doorbreken']
# ['teamName | PEC', 'teamName | zwartgele', 'incidentType | probeerde_de_muur_te_doorbreken']
# ['teamName | PEC', 'teamName | zwartgele', 'incidentType | probeerde_de_muur_te_doorbreken']
# ['goalName | Bryan_Linssen', 'incidentType | spannend_werd_het_niet_meer']
# ['goalName | Bryan_Linssen', 'incidentType | spannend_werd_het_niet_meer']
# ['redCardName | Linssen', 'matchTime | slotfase', 'cause | natrappen']
# ['redCardName | Linssen', 'matchTime | slotfase', 'cause | natrappen']
# ['redCardName | Linssen', 'matchTime | slotfase', 'cause | natrappen']
# ['hasTiedTeam | SC_Cambuur', 'incidentType | weet_bijna_niet_meer_wat_winnen_is']
# ['hasTiedTeam | SC_Cambuur', 'incidentType | weet_bijna_niet_meer_wat_winnen_is']
# ['temperatureCelsius | 8°C', 'temperatureCelsius | 13°C', 'timePoint | middagtemperaturen', 'locationArea | in_het_noordoosten', 'locationArea | in_het_midden_en_zuiden']
# ['temperatureCelsius | 8°C', 'temperatureCelsius | 13°C', 'timePoint | middagtemperaturen', 'locationArea | in_het_noordoosten', 'locationArea | in_het_midden_en_zuiden']
# ['temperatureCelsius | 8°C', 'temperatureCelsius | 13°C', 'timePoint | middagtemperaturen', 'locationArea | in_het_noordoosten', 'locationArea | in_het_midden_en_zuiden']
# ['temperatureCelsius | 8°C', 'temperatureCelsius | 13°C', 'timePoint | middagtemperaturen', 'locationArea | in_het_noordoosten', 'locationArea | in_het_midden_en_zuiden']
# ['temperatureCelsius | 8°C', 'temperatureCelsius | 13°C', 'timePoint | middagtemperaturen', 'locationArea | in_het_noordoosten', 'locationArea | in_het_midden_en_zuiden']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['locationArea | overal', 'windSpeedBft | 6-7', 'timePoint | in_de_loop_van_de_ochtend_en_middag', 'compassDirection | draait_zuidwest', 'weatherIntensity | vrij_krachtig', 'weatherIntensity | krachtig_tot_hard', 'locationArea | aan_zee_en_op_het_IJsselmeer']
# ['weatherFrequency | even', 'weatherType | buien', 'weatherType | zon', 'weatherChange | breekt_door']
# ['weatherFrequency | even', 'weatherType | buien', 'weatherType | zon', 'weatherChange | breekt_door']
# ['weatherFrequency | even', 'weatherType | buien', 'weatherType | zon', 'weatherChange | breekt_door']
# ['weatherFrequency | even', 'weatherType | buien', 'weatherType | zon', 'weatherChange | breekt_door']
# ['windAmount | matig', 'windDirection | noordoostenwind', 'locationArea | aan_de_kust_en_op_het_IJsselmeer', 'weatherIntesity | (vrij)_krachtig']
# ['windAmount | matig', 'windDirection | noordoostenwind', 'locationArea | aan_de_kust_en_op_het_IJsselmeer', 'weatherIntesity | (vrij)_krachtig']
# ['windAmount | matig', 'windDirection | noordoostenwind', 'locationArea | aan_de_kust_en_op_het_IJsselmeer', 'weatherIntesity | (vrij)_krachtig']
# ['windAmount | matig', 'windDirection | noordoostenwind', 'locationArea | aan_de_kust_en_op_het_IJsselmeer', 'weatherIntesity | (vrij)_krachtig']
# ['weatherType | helder', 'timePoint | Komende_nacht']
# ['weatherType | helder', 'timePoint | Komende_nacht']
# ['weatherType | droog', 'weatherChange | blijft']
# ['weatherType | droog', 'weatherChange | blijft']
# ['weatherType | grondmist', 'weatherFrequency | hier_en_daar']
# ['weatherType | grondmist', 'weatherFrequency | hier_en_daar']
# ['timePoint | Morgen', 'weatherChange | nog_niet_veel']
# ['timePoint | Morgen', 'weatherChange | nog_niet_veel']
# ['timePoint | Vannacht', 'weatherType | helder', 'weatherType | droog', 'weatherChange | blijft']
# ['timePoint | Vannacht', 'weatherType | helder', 'weatherType | droog', 'weatherChange | blijft']
# ['timePoint | Vannacht', 'weatherType | helder', 'weatherType | droog', 'weatherChange | blijft']
# ['timePoint | Vannacht', 'weatherType | helder', 'weatherType | droog', 'weatherChange | blijft']
# ['maximumTemperature | 25°C', 'maximumTemperature | 31°C', 'locationArea | op_de_Wadden', 'locationArea | in_het_zuidoosten_en_oosten']
# ['maximumTemperature | 25°C', 'maximumTemperature | 31°C', 'locationArea | op_de_Wadden', 'locationArea | in_het_zuidoosten_en_oosten']
# ['maximumTemperature | 25°C', 'maximumTemperature | 31°C', 'locationArea | op_de_Wadden', 'locationArea | in_het_zuidoosten_en_oosten']
# ['maximumTemperature | 25°C', 'maximumTemperature | 31°C', 'locationArea | op_de_Wadden', 'locationArea | in_het_zuidoosten_en_oosten']
# ['weatherType | onweer', 'weatherFrequency | kan_voorkomen']
# ['weatherType | onweer', 'weatherFrequency | kan_voorkomen']
# ['precipitationAmount | veel', 'incidentType | wateroverlast_kan_zorgen', 'locationArea | Plaatselijk']
# ['precipitationAmount | veel', 'incidentType | wateroverlast_kan_zorgen', 'locationArea | Plaatselijk']
# ['precipitationAmount | veel', 'incidentType | wateroverlast_kan_zorgen', 'locationArea | Plaatselijk']
# ['maximumTemperature | 10°C', 'maximumTemperature | 15°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden']
# ['maximumTemperature | 10°C', 'maximumTemperature | 15°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden']
# ['maximumTemperature | 10°C', 'maximumTemperature | 15°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden']
# ['maximumTemperature | 10°C', 'maximumTemperature | 15°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden']
# ['locationArea | Elders', 'weatherType | droog_met_opklaringen', 'timePoint | aanvankelijk']
# ['locationArea | Elders', 'weatherType | droog_met_opklaringen', 'timePoint | aanvankelijk']
# ['locationArea | Elders', 'weatherType | droog_met_opklaringen', 'timePoint | aanvankelijk']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten', 'locationArea | in_het_zuiden']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten', 'locationArea | in_het_zuiden']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten', 'locationArea | in_het_zuiden']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten', 'locationArea | in_het_zuiden']
# ['timePoint | Morgen_overdag', 'weatherType | zonnige', 'weatherType | bui', 'weatherChange | afgewisseld']
# ['timePoint | Morgen_overdag', 'weatherType | zonnige', 'weatherType | bui', 'weatherChange | afgewisseld']
# ['timePoint | Morgen_overdag', 'weatherType | zonnige', 'weatherType | bui', 'weatherChange | afgewisseld']
# ['timePoint | Morgen_overdag', 'weatherType | zonnige', 'weatherType | bui', 'weatherChange | afgewisseld']
# ['minimumTemperature | 1°C', 'weatherArea | lokaal_in_het_noordoosten', 'minimumTemperature | 8°C', 'weatherArea | in_het_zuidwesten']
# ['minimumTemperature | 1°C', 'weatherArea | lokaal_in_het_noordoosten', 'minimumTemperature | 8°C', 'weatherArea | in_het_zuidwesten']
# ['minimumTemperature | 1°C', 'weatherArea | lokaal_in_het_noordoosten', 'minimumTemperature | 8°C', 'weatherArea | in_het_zuidwesten']
# ['minimumTemperature | 1°C', 'weatherArea | lokaal_in_het_noordoosten', 'minimumTemperature | 8°C', 'weatherArea | in_het_zuidwesten']
# ['windAmount | overwegend_matige', 'windDirection | oostelijke']
# ['windAmount | overwegend_matige', 'windDirection | oostelijke']
# ['temperatureCelsius | 12°C', 'temperatureCelsius | 15°C', 'locationArea | in_het_noordoosten', 'locationArea | het_uiterste_zuiden', 'timePoint | middagtemperatuur']
# ['temperatureCelsius | 12°C', 'temperatureCelsius | 15°C', 'locationArea | in_het_noordoosten', 'locationArea | het_uiterste_zuiden', 'timePoint | middagtemperatuur']
# ['temperatureCelsius | 12°C', 'temperatureCelsius | 15°C', 'locationArea | in_het_noordoosten', 'locationArea | het_uiterste_zuiden', 'timePoint | middagtemperatuur']
# ['temperatureCelsius | 12°C', 'temperatureCelsius | 15°C', 'locationArea | in_het_noordoosten', 'locationArea | het_uiterste_zuiden', 'timePoint | middagtemperatuur']
# ['temperatureCelsius | 12°C', 'temperatureCelsius | 15°C', 'locationArea | in_het_noordoosten', 'locationArea | het_uiterste_zuiden', 'timePoint | middagtemperatuur']
# ['locationArea | in_het_westen_en_noordwesten', 'weatherType | nevelig']
# ['locationArea | in_het_westen_en_noordwesten', 'weatherType | nevelig']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten_en_oosten', 'locationArea | Zeeland']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten_en_oosten', 'locationArea | Zeeland']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten_en_oosten', 'locationArea | Zeeland']
# ['minimumTemperature | 6°C', 'minimumTemperature | 10°C', 'locationArea | in_het_noordoosten_en_oosten', 'locationArea | Zeeland']
# ['maximumtemperatuur | 16°C', 'maximumtemperatuur | 19°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden_van_het_land']
# ['maximumtemperatuur | 16°C', 'maximumtemperatuur | 19°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden_van_het_land']
# ['maximumtemperatuur | 16°C', 'maximumtemperatuur | 19°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden_van_het_land']
# ['maximumtemperatuur | 16°C', 'maximumtemperatuur | 19°C', 'locationArea | in_het_noorden', 'locationArea | in_het_zuiden_van_het_land']

# %%
full_count_test
# Out:
# Counter({'victimGender': 41,
#          'victimNumber': 53,
#          'victimStatus': 92,
#          'shootingType': 26,
#          'victimAge_Group': 8,
#          'accidentAddress': 12,
#          'accidentDate': 5,
#          'location': 49,
#          'datetime': 19,
#          'suspectStatus': 36,
#          'suspectWeapon': 3,
#          'ORG': 45,
#          'victimName': 22,
#          'suspectVehicle': 13,
#          'victimAge': 33,
#          'takenToHospital': 14,
#          'hospitalName': 7,
#          'incidentType': 240,
#          'cause ': 1,
#          'suspectDescription': 7,
#          'suspectGender': 12,
#          'suspectRace': 1,
#          'cause': 46,
#          'competitionName': 11,
#          'teamName': 74,
#          'suspectName': 7,
#          'supsectStatus': 1,
#          'suspectNumber': 4,
#          'personnelArrivedTime': 4,
#          'victimBased': 6,
#          'suspectOccupation': 1,
#          'suspectAge_Group': 1,
#          'pitcherName': 15,
#          'incedentType': 2,
#          'gameTally': 1,
#          'fielderPosition': 3,
#          'gameNumber': 5,
#          'batterName': 29,
#          'incidenType': 1,
#          'winLossRecord': 1,
#          'teamRecord': 3,
#          'timePoint': 49,
#          'RBI': 4,
#          'pitcherRecord': 2,
#          'matchTime': 28,
#          'strikeOutNumber': 1,
#          'strikingType': 5,
#          'pitchCount': 2,
#          'atBatNumber': 1,
#          'homeRunNumber': 2,
#          'pitchResult': 2,
#          'pitchRecord': 1,
#          'walkNumber': 1,
#          'fielderName': 6,
#          'inningsPitched': 2,
#          'winLossType': 1,
#          'inningNumber': 1,
#          'matchDate': 4,
#          'matchStreakType': 7,
#          'hitNumber': 1,
#          'locationPlayed': 3,
#          'baseNumber': 1,
#          'baseReachedNumber': 1,
#          'victimRace': 1,
#          'playerName': 12,
#          'injuryType': 1,
#          'outNumber': 1,
#          'weatherType': 20,
#          'temperatureChange': 2,
#          'temperatureCelsius': 10,
#          'weatherIntensity': 4,
#          'windAmount': 5,
#          'weatherFrequency': 4,
#          'weatherChange': 13,
#          'locationArea': 27,
#          'pitchNumber': 1,
#          'victimAmount': 8,
#          'victimVehicle': 28,
#          'victimDescription': 2,
#          'suspectAge': 3,
#          'incident': 1,
#          'suspectBased': 1,
#          'disallowedGoalName': 1,
#          'matchStreakNumber': 3,
#          'goalScore': 13,
#          'goalType': 4,
#          'positionOfPlayer': 5,
#          'assistType': 2,
#          'hasWonTeam': 4,
#          'goalName': 10,
#          'coachName': 6,
#          'stadiumPlayed': 5,
#          'tackleRecipientName': 2,
#          'tackleGiverName': 3,
#          'chanceForType': 7,
#          'playerNationality': 4,
#          'teamStandings': 3,
#          'hasLostTeam': 3,
#          'refereeName': 3,
#          'chanceForNumber': 1,
#          'chanceForName': 8,
#          'homeAway': 3,
#          'goalkeeperName': 5,
#          'numberOfPoints': 3,
#          'hasTiedTeam': 2,
#          'finalScore': 1,
#          'substituteName': 1,
#          'injuredName': 1,
#          'injuredType': 1,
#          'redCardName': 3,
#          'numberOfMatchGoals': 1,
#          'windSpeedBft': 1,
#          'compassDirection': 1,
#          'windDirection': 2,
#          'weatherIntesity': 1,
#          'maximumTemperature': 4,
#          'precipitationAmount': 1,
#          'minimumTemperature': 6,
#          'weatherArea': 2,
#          'maximumtemperatuur': 2})
